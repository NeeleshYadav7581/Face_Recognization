# %%
from deepface import DeepFace
import cv2 
import matplotlib.pyplot as plt

# %%
img_1 = cv2.imread('C:\\Users\\admin\\Face_Recognization\\Images\\Neelu_04.jpg')
plt.imshow(img_1[:,:,::-1])
plt.show()

# %%
img_2 = cv2.imread('C:\\Users\\admin\\Face_Recognization\\Images\\Neelu_08.jpg')
plt.imshow(img_2[:,:,::-1])
plt.show()

# %%
result = DeepFace.verify(img_1,img_2)

# %%
similarity_score = 1 - result["distance"]
print("Similarity Score:-->", similarity_score)
print("These peoples are same: --> " , result["verified"])
# Out:
# Similarity Score:--> 0.7111368051718016
# These peoples are same: -->  True
